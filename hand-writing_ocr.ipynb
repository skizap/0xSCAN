# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvalgupta2003/0xSCAN/blob/master/hand-writing_ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q keras-ocr

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(img) for img in ['//content/WhatsApp Image 2021-09-26 at 09.27.33.jpeg'   
                                        
    ]
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66649bdc9cfb> in <module>()
#       1 images = [
# ----> 2     keras_ocr.tools.read(img) for img in ['//content/WhatsApp Image 2021-09-26 at 09.27.33.jpeg'
#       3
#       4     ]
#       5 ]
#
# <ipython-input-1-66649bdc9cfb> in <listcomp>(.0)
#       1 images = [
# ----> 2     keras_ocr.tools.read(img) for img in ['//content/WhatsApp Image 2021-09-26 at 09.27.33.jpeg'
#       3
#       4     ]
#       5 ]
#
# NameError: name 'keras_ocr' is not defined

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[0])

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[1])

# %%
prediction_groups = pipeline.recognize(images)

print(prediction_groups)
#for i in prediction_group[0]:
  #print(i[0])
type(prediction_groups)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-73698e744c19> in <module>()
# ----> 1 prediction_groups = pipeline.recognize(images)
#       2 print(prediction_groups)
#       3 type(prediction_groups)
#
# NameError: name 'pipeline' is not defined

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, 
                                    predictions=predictions, 
                                    ax=ax)
